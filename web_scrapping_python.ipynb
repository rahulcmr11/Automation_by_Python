# %%
import requests

from bs4 import BeautifulSoup

r = requests.get("http://www.pyclass.com/example.html", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
r
c = r.content
c
soup = BeautifulSoup(c,"html.parser")
#print(soup.prettify())
all = soup.find_all("div",{"class":"cities"})
all
type(all)
len(all)
all[0].find_all("h2")[0].text
#x = [city for city in all city.find_all("h2")[0].text]
for item in all:
    print(item.find_all("p")[0].text)
    #print()
x
*** THE OTHER REAL WORLD PART ***
#r1 = requests.get("https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
#r1 = requests.get("http://www.century21.com/for-sale-homes/Rock-Springs-WI-49532c/")
r1 = requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa,Residential-Plot&Locality=Whitefield&cityName=Bangalore")
content2 = r1.content

#content2

soup1 = BeautifulSoup(content2,"html.parser")

#print(soup1.prettify())

#all_2 = soup1.find_all("div",{"class":"l-srp__container flex relative clearfix"})#,"aria-label":"property"
all_2 = soup1.find_all("span",{"class":"m-srp-card__price"})#,"aria-label":"property"
#all_2[0].find("span",{"class":"m-srp-card__price"})#,"aria-label":"property"
#society[1].text.replace("\n","").replace("Society:","")
society = soup1.find_all("div",{"class":"m-srp-card__society"})
all_2[1].text

#len(all_2) #[20].text

len(all_2)

l =[]
for item in range(0,len(all_2)):
    #print(all_2[item].text)
    d={}
    d['price']=all_2[item].text
    d['apt']=society[item].text.replace("\n","").replace("Society:","")
    #print(society[item].text)
    #print(" ")
    l.append(d)

l

import pandas as pd


df = pd.DataFrame(l)

df
